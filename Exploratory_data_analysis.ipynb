# %%
import h5py    
import numpy as np
import pandas as pd
import datetime
from termcolor import colored

# %% [markdown]
# ### Take dataset with hdf5 format

# %%
sets = ['dev', 'test']
filename = 'N-CMAPSS_DS03-012.h5'

# %% [markdown]
# ### Read file and rename columns

# %%
with h5py.File(filename, 'r') as hdf:
        
    for s in sets:

        globals()[f"theta_{s}"] = pd.DataFrame(np.array(hdf.get(f'T_{s}')), 
                                                       columns=np.array(hdf.get('T_var')).astype('U'))
        globals()[f"xv_{s}"] = pd.DataFrame(np.array(hdf.get(f'X_v_{s}')), 
                                                   columns=np.array(hdf.get('X_v_var')).astype('U'))
        globals()[f"xs_{s}"] = pd.DataFrame(np.array(hdf.get(f'X_s_{s}')), 
                                                   columns=np.array(hdf.get('X_s_var')).astype('U'))
        globals()[f"w_{s}"] = pd.DataFrame(np.array(hdf.get(f'W_{s}')), 
                                                   columns=np.array(hdf.get('W_var')).astype('U'))
        globals()[f"aux_{s}"] = pd.DataFrame(np.array(hdf.get(f'A_{s}')), 
                                                   columns=np.array(hdf.get('A_var')).astype('U')).astype('int64')

        globals()[f"y_{s}"] = pd.DataFrame(np.array(hdf.get(f'Y_{s}')), columns=['RUL'])


        #### RENAME COLUMNS

        globals()[f"w_{s}"].rename(columns={'alt':'Altitude'}, inplace=True)

        globals()[f"aux_{s}"].rename(columns={'unit':'Unit','cycle':'Cycle','Fc':'Class','hs':'State'},
                                           inplace=True)
        globals()[f"theta_{s}"].rename(columns={'fan_eff_mod':'Fan_eff_mod','fan_flow_mod':'Fan_flow_mod'},
                                             inplace=True)

# %% [markdown]
# ### Check if there are observations with missing values

# %%
dev_tmp = pd.concat([aux_dev, w_dev, xs_dev, xv_dev, theta_dev, y_dev], axis=1)


print(f'The dev dataset comprises of {len(dev_tmp):,} observations and there are {len(dev_tmp) - len(dev_tmp.dropna())} missing values\n\n'
      f'The features include: {len(theta_dev.columns)} '.replace(',','.') +
      f'health parameters, {len(xs_dev.columns)} sensors, {len(xv_dev.columns)} virtual sensors, '
      f'{len(aux_dev.columns)} auxiliary data, {len(w_dev.columns)} scenario descriptors and {len(y_dev.columns)} '
      f'output variable\n')
    
del(dev_tmp)
    

test_tmp = pd.concat([aux_test, w_test, xs_test, xv_test, theta_test, y_test], axis=1)

print(f'The test dataset comprises of {len(test_tmp):,} observations and there are {len(test_tmp) - len(test_tmp.dropna())} missing values\n\n'
      f'The features include: {len(theta_test.columns)} '.replace(',','.') + 
      f'health parameters, {len(xs_test.columns)} sensors, {len(xv_test.columns)} virtual sensors, '
      f'{len(aux_test.columns)} auxiliary data, {len(w_test.columns)} scenario descriptors and {len(y_test.columns)} '
      f'output variable')
    
del(test_tmp)
# Out:
# The dev dataset comprises of 5.571.277 observations and there are 0 missing values
#
# The features include: 10 health parameters, 14 sensors, 14 virtual sensors, 4 auxiliary data, 4 scenario descriptors and 1 output variable
#
# The test dataset comprises of 4.251.560 observations and there are 0 missing values
#
# The features include: 10 health parameters, 14 sensors, 14 virtual sensors, 4 auxiliary data, 4 scenario descriptors and 1 output variable

# %% [markdown]
# ## Quick analysis of the two datasets

# %%
dev = pd.concat([aux_dev, y_dev], axis=1)
test = pd.concat([aux_test, y_test], axis=1)

# %% [markdown]
# ### How many units and fight classes
#
# The units are divided into three flight classes depending on whether the unit is operating short-length flights (i.e., flight class 1), medium-length flights (i.e., flight class 2), or long-length flights (i.e., flight class 3)
#
# | Flight Class   | Flight Length [h]
# | :-----------:  | :-----------:
# | 1              |    1 to 3
# | 2              |    3 to 5
# | 3              |    5 to 7

# %%
print("The dev units: ", end = "")
print(*aux_dev['Unit'].unique(), sep = ", ", end = "  and  ")
print("the test units: ", end = "")
print(*aux_test['Unit'].unique(), sep = ", ")  


print("\nThe dev flight classes: ", end = "") 
print(*np.sort(aux_dev['Class'].unique()), sep = ", ", end = "  and  ")
print("the test flight classes: ", end = "") 
print(*np.sort(aux_test['Class'].unique()), sep = ", ")
# Out:
# The dev units: 1, 2, 3, 4, 5, 6, 7, 8, 9  and  the test units: 10, 11, 12, 13, 14, 15
#
# The dev flight classes: 1, 2, 3  and  the test flight classes: 1, 2, 3

# %% [markdown]
# The dev units are different from the test ones. Each unit has its proper flight class

# %%
unit_data = {}

for unit in list(dev['Unit'].unique()):
    
    unit_data[unit] = dev[(dev['Unit'] == unit)]
    unit_data[unit].reset_index(drop=True, inplace=True)
    
    print(f"Dev unit {unit} has flight class: {unit_data[unit]['Class'].unique()[0]}")
    
for unit in list(test['Unit'].unique()):
    
    unit_data[unit] = test[(test['Unit'] == unit)]
    unit_data[unit].reset_index(drop=True, inplace=True)
    
    print(f"Test unit {unit} has flight class: {unit_data[unit]['Class'].unique()[0]}")
# Out:
# Dev unit 1 has flight class: 1
# Dev unit 2 has flight class: 2
# Dev unit 3 has flight class: 2
# Dev unit 4 has flight class: 2
# Dev unit 5 has flight class: 1
# Dev unit 6 has flight class: 3
# Dev unit 7 has flight class: 2
# Dev unit 8 has flight class: 3
# Dev unit 9 has flight class: 1
# Test unit 10 has flight class: 3
# Test unit 11 has flight class: 3
# Test unit 12 has flight class: 1
# Test unit 13 has flight class: 3
# Test unit 14 has flight class: 1
# Test unit 15 has flight class: 2

# %% [markdown]
# ### Check if cycle and rul are perfectly linear

# %%
for unit in list(dev['Unit'].unique()):
    
    cycle = 1
    rul = unit_data[unit]["RUL"].iloc[0]
    
    while rul >= 0:
    
        if not (unit_data[unit][unit_data[unit]['Cycle'] == cycle].equals(unit_data[unit][unit_data[unit]['RUL'] == rul])):
            print('Not linear')
        
        cycle = cycle + 1
        rul = rul - 1
    
    
for unit in list(test['Unit'].unique()):
    
    cycle = 1
    rul = unit_data[unit]["RUL"].iloc[0]
    
    while rul >= 0:
    
        if not (unit_data[unit][unit_data[unit]['Cycle'] == cycle].equals(unit_data[unit][unit_data[unit]['RUL'] == rul])):
            print('Not linear')
        
        cycle = cycle + 1
        rul = rul - 1

# %% [markdown]
# ### Find the transition times
# The time in which the transition from normal to abnormal degradation starts, i.e. the onset of a fault, is called transition time t<sub>s</sub>.

# %%
ts = {}
for unit in list(dev['Unit'].unique()):

    ts[unit] = unit_data[unit][unit_data[unit]['State'] == 0]["Cycle"].iloc[0]
    print(f'Dev unit {unit}: {unit_data[unit]["Cycle"].iloc[-1]  - ts[unit]} remaining cycles')

for unit in list(test['Unit'].unique()):

    ts[unit] = unit_data[unit][unit_data[unit]['State'] == 0]["Cycle"].iloc[0]
    print(f'Test unit {unit}: {unit_data[unit]["Cycle"].iloc[-1]  - ts[unit]} remaining cycles')
# Out:
# Dev unit 1: 35 remaining cycles
# Dev unit 2: 49 remaining cycles
# Dev unit 3: 42 remaining cycles
# Dev unit 4: 36 remaining cycles
# Dev unit 5: 55 remaining cycles
# Dev unit 6: 45 remaining cycles
# Dev unit 7: 55 remaining cycles
# Dev unit 8: 53 remaining cycles
# Dev unit 9: 47 remaining cycles
# Test unit 10: 48 remaining cycles
# Test unit 11: 40 remaining cycles
# Test unit 12: 56 remaining cycles
# Test unit 13: 58 remaining cycles
# Test unit 14: 40 remaining cycles
# Test unit 15: 42 remaining cycles

# %%
ts = {}
for unit in list(dev['Unit'].unique()):

    ts[unit] = unit_data[unit][unit_data[unit]['State'] == 0]["Cycle"].iloc[0]
    print(f'Transition time of dev unit {unit}: {ts[unit]} / {unit_data[unit]["Cycle"].iloc[-1]} total cycles')

print('\n')
for unit in list(test['Unit'].unique()):

    ts[unit] = unit_data[unit][unit_data[unit]['State'] == 0]["Cycle"].iloc[0]
    print(f'Transition time of test unit {unit}: {ts[unit]} / {unit_data[unit]["Cycle"].iloc[-1]} total cycles')
# Out:
# Transition time of dev unit 1: 37 / 72 total cycles
# Transition time of dev unit 2: 24 / 73 total cycles
# Transition time of dev unit 3: 25 / 67 total cycles
# Transition time of dev unit 4: 24 / 60 total cycles
# Transition time of dev unit 5: 38 / 93 total cycles
# Transition time of dev unit 6: 18 / 63 total cycles
# Transition time of dev unit 7: 25 / 80 total cycles
# Transition time of dev unit 8: 18 / 71 total cycles
# Transition time of dev unit 9: 37 / 84 total cycles
#
#
# Transition time of test unit 10: 18 / 66 total cycles
# Transition time of test unit 11: 19 / 59 total cycles
# Transition time of test unit 12: 37 / 93 total cycles
# Transition time of test unit 13: 19 / 77 total cycles
# Transition time of test unit 14: 36 / 76 total cycles
# Transition time of test unit 15: 25 / 67 total cycles

# %% [markdown]
# ### Check if any fault data occur in time t<sub>s</sub>

# %%
for unit in list(dev['Unit'].unique()):
    
    if not (unit_data[unit][unit_data[unit]['State'] == 0].equals(unit_data[unit][unit_data[unit]['Cycle'] >= ts[unit]])):
        print('Not corresponding')

for unit in list(test['Unit'].unique()):
    
    if not (unit_data[unit][unit_data[unit]['State'] == 0].equals(unit_data[unit][unit_data[unit]['Cycle'] >= ts[unit]])):
        print('Not corresponding')

# %% [markdown]
# ## Analysis of the failures

# %%
dev = pd.concat([aux_dev[['Unit','State']], theta_dev], axis=1)
test = pd.concat([aux_test[['Unit','State']], theta_test], axis=1)

# %%
unit_data = {}

for unit in list(dev['Unit'].unique()):
    
    unit_data[unit] = dev[(dev['Unit'] == unit)]
    unit_data[unit].reset_index(drop=True, inplace=True)
    
for unit in list(test['Unit'].unique()):
    
    unit_data[unit] = test[(test['Unit'] == unit)]
    unit_data[unit].reset_index(drop=True, inplace=True)

# %% [markdown]
# All the rotating sub-components of the engine i.e., fan, low pressure compressor (LPC), high pressure compressor (HPC), low pressure turbine (LPT) and high pressure turbine (HPT) can be affected by degradation in flow and efficiency. So there are a total of 5 components and 10 possible types of degradation. However the distinctive failure modes are only 7.
# As an example Dataset 2, has two different failure modes: HPT eff and LPT flow/eff + HPT eff.

# %%
unit_theta = {}

for unit in list(dev['Unit'].unique()):
    
    unit_theta[unit] = unit_data[unit][unit_data[unit] != 0].dropna(how='any', axis=1).drop('Unit', axis=1)
    
    components = []
    for component in unit_theta[unit].columns:
        components.append(component[:3])
    
    print(f"The components of dev unit {unit} affected by degradation: ", end = "")
    print(*set(components), sep=", ", end=" (")
    print(*unit_theta[unit].columns, sep=", ", end = " )\n")
    
for unit in list(test['Unit'].unique()):
    
    unit_theta[unit] = unit_data[unit][unit_data[unit] != 0].dropna(how='any', axis=1).drop('Unit', axis=1)
    
    components = []
    for component in unit_theta[unit].columns:
        components.append(component[:3])

    print(f"The components of test unit {unit} affected by degradation: ", end = "")
    print(*set(components), sep=", ", end=" (")
    print(*unit_theta[unit].columns, sep=", ", end = " )\n")
# Out:
# The components of dev unit 1 affected by degradation: LPT, HPT (HPT_eff_mod, LPT_eff_mod, LPT_flow_mod )
# The components of dev unit 2 affected by degradation: LPT, HPT (HPT_eff_mod, LPT_eff_mod, LPT_flow_mod )
# The components of dev unit 3 affected by degradation: LPT, HPT (HPT_eff_mod, LPT_eff_mod, LPT_flow_mod )
# The components of dev unit 4 affected by degradation: LPT, HPT (HPT_eff_mod, LPT_eff_mod, LPT_flow_mod )
# The components of dev unit 5 affected by degradation: LPT, HPT (HPT_eff_mod, LPT_eff_mod, LPT_flow_mod )
# The components of dev unit 6 affected by degradation: LPT, HPT (HPT_eff_mod, LPT_eff_mod, LPT_flow_mod )
# The components of dev unit 7 affected by degradation: LPT, HPT (HPT_eff_mod, LPT_eff_mod, LPT_flow_mod )
# The components of dev unit 8 affected by degradation: LPT, HPT (HPT_eff_mod, LPT_eff_mod, LPT_flow_mod )
# The components of dev unit 9 affected by degradation: LPT, HPT (HPT_eff_mod, LPT_eff_mod, LPT_flow_mod )
# The components of test unit 10 affected by degradation: LPT, HPT (HPT_eff_mod, LPT_eff_mod, LPT_flow_mod )
# The components of test unit 11 affected by degradation: LPT, HPT (HPT_eff_mod, LPT_eff_mod, LPT_flow_mod )
# The components of test unit 12 affected by degradation: LPT, HPT (HPT_eff_mod, LPT_eff_mod, LPT_flow_mod )
# The components of test unit 13 affected by degradation: LPT, HPT (HPT_eff_mod, LPT_eff_mod, LPT_flow_mod )
# The components of test unit 14 affected by degradation: LPT, HPT (HPT_eff_mod, LPT_eff_mod, LPT_flow_mod )
# The components of test unit 15 affected by degradation: LPT, HPT (HPT_eff_mod, LPT_eff_mod, LPT_flow_mod )

# %%
normal_theta = {}
abnormal_theta = {}

for unit in list(dev['Unit'].unique()):
    
    cols = unit_theta[unit].columns
    normal_theta[unit] = unit_data[unit][unit_data[unit]['State'] == 1][cols]
    print(f'The mean for the dev unit {unit} in normal condition:\n'
          f'{normal_theta[unit].drop_duplicates().mean()}')
    abnormal_theta[unit] = unit_data[unit][unit_data[unit]['State'] == 0][cols]
    print(f'The mean for the dev unit {unit} in abnormal condition:\n'
          f'{abnormal_theta[unit].drop_duplicates().mean()}\n')

    
for unit in list(test['Unit'].unique()):

    cols = unit_theta[unit].columns
    normal_theta[unit] = unit_data[unit][unit_data[unit]['State'] == 1][cols]
    print(f'The mean for the test unit {unit} in normal condition:\n'
          f'{normal_theta[unit].drop_duplicates().mean()}')
    abnormal_theta[unit] = unit_data[unit][unit_data[unit]['State'] == 0][cols]
    print(f'The mean for the test unit {unit} in abnormal condition:\n'
          f'{abnormal_theta[unit].drop_duplicates().mean()}\n')
# Out:
# The mean for the dev unit 1 in normal condition:
# HPT_eff_mod    -0.000643
# LPT_eff_mod    -0.000645
# LPT_flow_mod   -0.001138
# dtype: float64
# The mean for the dev unit 1 in abnormal condition:
# HPT_eff_mod    -0.001922
# LPT_eff_mod    -0.001988
# LPT_flow_mod   -0.007010
# dtype: float64
#
# The mean for the dev unit 2 in normal condition:
# HPT_eff_mod    -0.000650
# LPT_eff_mod    -0.000503
# LPT_flow_mod   -0.000311
# dtype: float64
# The mean for the dev unit 2 in abnormal condition:
# HPT_eff_mod    -0.002728
# LPT_eff_mod    -0.002701
# LPT_flow_mod   -0.005757
# dtype: float64
#
# The mean for the dev unit 3 in normal condition:
# HPT_eff_mod    -0.000312
# LPT_eff_mod    -0.001109
# LPT_flow_mod   -0.000362
# dtype: float64
# The mean for the dev unit 3 in abnormal condition:
# HPT_eff_mod    -0.001922
# LPT_eff_mod    -0.003659
# LPT_flow_mod   -0.006573
# dtype: float64
#
# The mean for the dev unit 4 in normal condition:
# HPT_eff_mod    -0.000739
# LPT_eff_mod    -0.000496
# LPT_flow_mod   -0.000733
# dtype: float64
# The mean for the dev unit 4 in abnormal condition:
# HPT_eff_mod    -0.002598
# LPT_eff_mod    -0.001415
# LPT_flow_mod   -0.005877
# dtype: float64
#
# The mean for the dev unit 5 in normal condition:
# HPT_eff_mod    -0.000927
# LPT_eff_mod    -0.000423
# LPT_flow_mod   -0.000412
# dtype: float64
# The mean for the dev unit 5 in abnormal condition:
# HPT_eff_mod    -0.002176
# LPT_eff_mod    -0.004909
# LPT_flow_mod   -0.006320
# dtype: float64
#
# The mean for the dev unit 6 in normal condition:
# HPT_eff_mod    -0.000834
# LPT_eff_mod    -0.000831
# LPT_flow_mod   -0.000803
# dtype: float64
# The mean for the dev unit 6 in abnormal condition:
# HPT_eff_mod    -0.003384
# LPT_eff_mod    -0.002379
# LPT_flow_mod   -0.005233
# dtype: float64
#
# The mean for the dev unit 7 in normal condition:
# HPT_eff_mod    -0.001101
# LPT_eff_mod    -0.000598
# LPT_flow_mod   -0.001102
# dtype: float64
# The mean for the dev unit 7 in abnormal condition:
# HPT_eff_mod    -0.003363
# LPT_eff_mod    -0.003225
# LPT_flow_mod   -0.005435
# dtype: float64
#
# The mean for the dev unit 8 in normal condition:
# HPT_eff_mod    -0.000558
# LPT_eff_mod    -0.000892
# LPT_flow_mod   -0.000723
# dtype: float64
# The mean for the dev unit 8 in abnormal condition:
# HPT_eff_mod    -0.002927
# LPT_eff_mod    -0.005303
# LPT_flow_mod   -0.003901
# dtype: float64
#
# The mean for the dev unit 9 in normal condition:
# HPT_eff_mod    -0.001039
# LPT_eff_mod    -0.001238
# LPT_flow_mod   -0.000373
# dtype: float64
# The mean for the dev unit 9 in abnormal condition:
# HPT_eff_mod    -0.004271
# LPT_eff_mod    -0.003774
# LPT_flow_mod   -0.003227
# dtype: float64
#
# The mean for the test unit 10 in normal condition:
# HPT_eff_mod    -0.000285
# LPT_eff_mod    -0.000139
# LPT_flow_mod   -0.001121
# dtype: float64
# The mean for the test unit 10 in abnormal condition:
# HPT_eff_mod    -0.002729
# LPT_eff_mod    -0.005860
# LPT_flow_mod   -0.002884
# dtype: float64
#
# The mean for the test unit 11 in normal condition:
# HPT_eff_mod    -0.000801
# LPT_eff_mod    -0.000329
# LPT_flow_mod   -0.000767
# dtype: float64
# The mean for the test unit 11 in abnormal condition:
# HPT_eff_mod    -0.004202
# LPT_eff_mod    -0.001751
# LPT_flow_mod   -0.004277
# dtype: float64
#
# The mean for the test unit 12 in normal condition:
# HPT_eff_mod    -0.001296
# LPT_eff_mod    -0.001077
# LPT_flow_mod   -0.000631
# dtype: float64
# The mean for the test unit 12 in abnormal condition:
# HPT_eff_mod    -0.004564
# LPT_eff_mod    -0.003448
# LPT_flow_mod   -0.003095
# dtype: float64
#
# The mean for the test unit 13 in normal condition:
# HPT_eff_mod    -0.000677
# LPT_eff_mod    -0.000846
# LPT_flow_mod   -0.000769
# dtype: float64
# The mean for the test unit 13 in abnormal condition:
# HPT_eff_mod    -0.003073
# LPT_eff_mod    -0.006540
# LPT_flow_mod   -0.002778
# dtype: float64
#
# The mean for the test unit 14 in normal condition:
# HPT_eff_mod    -0.001077
# LPT_eff_mod    -0.000811
# LPT_flow_mod   -0.000730
# dtype: float64
# The mean for the test unit 14 in abnormal condition:
# HPT_eff_mod    -0.003270
# LPT_eff_mod    -0.003674
# LPT_flow_mod   -0.006406
# dtype: float64
#
# The mean for the test unit 15 in normal condition:
# HPT_eff_mod    -0.000924
# LPT_eff_mod    -0.000768
# LPT_flow_mod   -0.000781
# dtype: float64
# The mean for the test unit 15 in abnormal condition:
# HPT_eff_mod    -0.003968
# LPT_eff_mod    -0.003983
# LPT_flow_mod   -0.004130
# dtype: float64

# %% [markdown]
# The between-flight maintenance is not explicitly modeled but is considered by the process noise, so the engine health parameters (flow and efficiency) can improve within allowable limits at any point and hence the loss in efficiency or flow is not locally monotonic

# %% [markdown]
# ## Analysis of the observations and timestamps

# %%
dev = pd.concat([aux_dev, y_dev], axis=1)
test = pd.concat([aux_test, y_test], axis=1)

# %%
unit_data = {}

for unit in list(dev['Unit'].unique()):
    
    unit_data[unit] = dev[(dev['Unit'] == unit)]
    unit_data[unit].reset_index(drop=True, inplace=True)
    
for unit in list(test['Unit'].unique()):
    
    unit_data[unit] = test[(test['Unit'] == unit)]
    unit_data[unit].reset_index(drop=True, inplace=True)

# %% [markdown]
# In the previous version, the sampling rate was defined at 1 Hz (1 sample every second). As it can be seen the sampling rate mismatches the relative flight class, however it doesn't differ too much from it and it isn't all the same

# %%
# Sampling rate in Hz
hertz = 1

for unit in list(dev['Unit'].unique()):
        
    in_h = unit_data[unit]['Class'].unique()[0] * 2 - 1
    end_h = in_h + 2
    
    print(f"\nUnit {unit} has flight class: {unit_data[unit]['Class'].unique()[0]} ({in_h}-{end_h} hours)\n")
    
    max_v = 0
    min_v = len(dev)

    for cycle in  range (1, unit_data[unit]["Cycle"].iloc[-1] + 1):

        cycle_len = len(unit_data[unit][unit_data[unit]["Cycle"] == cycle])
        
        if cycle_len >= max_v:
            max_v = cycle_len
            
        if cycle_len <= min_v:
            min_v = cycle_len
        
        time = str(datetime.timedelta(seconds= cycle_len // hertz)) 
               
        if int(time[0]) >= in_h and int(time[0]) <= end_h:
            print(colored(f"Cycle {cycle} lasts {time} hours ", 'green'))
        else:
            print(colored(f"Cycle {cycle} lasts {time} hours ", 'red'))
    
    print(f'\nMin value is {min_v}, max_value is {max_v}')
        
for unit in list(test['Unit'].unique()):
        
    in_h = unit_data[unit]['Class'].unique()[0] * 2 - 1
    end_h = in_h + 2
    
    print(f"\nUnit {unit} has flight class: {unit_data[unit]['Class'].unique()[0]} ({in_h}-{end_h} hours)\n")
    
    max_v = 0
    min_v = len(dev)
    
    for cycle in  range (1, unit_data[unit]["Cycle"].iloc[-1] + 1):

        cycle_len = len(unit_data[unit][unit_data[unit]["Cycle"] == cycle])
        
        if cycle_len >= max_v:
            max_v = cycle_len
            
        if cycle_len <= min_v:
            min_v = cycle_len
        
        time = str(datetime.timedelta(seconds= cycle_len // hertz)) 
        
        if int(time[0]) >= in_h and int(time[0]) <= end_h:
            print(colored(f"Cycle {cycle} lasts {time} hours ", 'green'))
        else:
            print(colored(f"Cycle {cycle} lasts {time} hours ", 'red'))
        
    print(f'\nMin value is {min_v}, max_value is {max_v}')
# Out:
# Unit 1 has flight class: 1 (1-3 hours)
#
# Cycle 1 lasts 1:34:37 hours
# Cycle 2 lasts 0:52:01 hours
# Cycle 3 lasts 1:14:22 hours
# Cycle 4 lasts 1:06:48 hours
# Cycle 5 lasts 1:34:37 hours
# Cycle 6 lasts 0:55:36 hours
# Cycle 7 lasts 1:14:58 hours
# Cycle 8 lasts 1:02:30 hours
# Cycle 9 lasts 1:25:30 hours
# Cycle 10 lasts 1:17:40 hours
# Cycle 11 lasts 1:06:48 hours
# Cycle 12 lasts 1:02:30 hours
# Cycle 13 lasts 1:09:41 hours
# Cycle 14 lasts 1:14:58 hours
# Cycle 15 lasts 1:14:58 hours
# Cycle 16 lasts 1:14:55 hours
# Cycle 17 lasts 1:02:30 hours
# Cycle 18 lasts 1:14:55 hours
# Cycle 19 lasts 0:58:24 hours
# Cycle 20 lasts 1:03:34 hours
# Cycle 21 lasts 1:29:15 hours
# Cycle 22 lasts 0:58:24 hours
# Cycle 23 lasts 1:34:37 hours
# Cycle 24 lasts 1:24:29 hours
# Cycle 25 lasts 1:09:41 hours
# Cycle 26 lasts 1:09:41 hours
# Cycle 27 lasts 1:25:30 hours
# Cycle 28 lasts 1:14:58 hours
# Cycle 29 lasts 1:03:34 hours
# Cycle 30 lasts 1:09:41 hours
# Cycle 31 lasts 1:06:48 hours
# Cycle 32 lasts 0:58:24 hours
# Cycle 33 lasts 1:25:30 hours
# Cycle 34 lasts 1:34:37 hours
# Cycle 35 lasts 0:55:36 hours
# Cycle 36 lasts 1:03:16 hours
# Cycle 37 lasts 1:03:34 hours
# Cycle 38 lasts 1:03:16 hours
# Cycle 39 lasts 1:02:30 hours
# Cycle 40 lasts 1:03:16 hours
# Cycle 41 lasts 1:34:37 hours
# Cycle 42 lasts 1:29:15 hours
# Cycle 43 lasts 1:14:22 hours
# Cycle 44 lasts 1:14:58 hours
# Cycle 45 lasts 0:52:01 hours
# Cycle 46 lasts 1:14:55 hours
# Cycle 47 lasts 1:09:41 hours
# Cycle 48 lasts 0:55:36 hours
# Cycle 49 lasts 1:03:34 hours
# Cycle 50 lasts 0:55:36 hours
# Cycle 51 lasts 1:34:37 hours
# Cycle 52 lasts 1:14:55 hours
# Cycle 53 lasts 1:14:58 hours
# Cycle 54 lasts 1:17:40 hours
# Cycle 55 lasts 1:25:30 hours
# Cycle 56 lasts 0:52:01 hours
# Cycle 57 lasts 1:22:38 hours
# Cycle 58 lasts 1:02:30 hours
# Cycle 59 lasts 0:55:36 hours
# Cycle 60 lasts 1:02:30 hours
# Cycle 61 lasts 0:58:24 hours
# Cycle 62 lasts 1:29:38 hours
# Cycle 63 lasts 0:58:24 hours
# Cycle 64 lasts 1:06:48 hours
# Cycle 65 lasts 0:58:24 hours
# Cycle 66 lasts 0:58:24 hours
# Cycle 67 lasts 1:14:22 hours
# Cycle 68 lasts 1:06:48 hours
# Cycle 69 lasts 1:22:38 hours
# Cycle 70 lasts 1:29:38 hours
# Cycle 71 lasts 1:14:22 hours
# Cycle 72 lasts 1:17:40 hours
#
# Min value is 3121, max_value is 5677
#
# Unit 2 has flight class: 2 (3-5 hours)
#
# Cycle 1 lasts 2:49:58 hours
# Cycle 2 lasts 2:18:40 hours
# Cycle 3 lasts 3:22:25 hours
# Cycle 4 lasts 3:13:23 hours
# Cycle 5 lasts 1:59:51 hours
# Cycle 6 lasts 2:01:25 hours
# Cycle 7 lasts 1:42:00 hours
# Cycle 8 lasts 2:43:10 hours
# Cycle 9 lasts 3:13:50 hours
# Cycle 10 lasts 2:55:32 hours
# Cycle 11 lasts 2:22:11 hours
# Cycle 12 lasts 2:30:34 hours
# Cycle 13 lasts 2:14:14 hours
# Cycle 14 lasts 3:24:10 hours
# Cycle 15 lasts 2:48:59 hours
# Cycle 16 lasts 2:58:49 hours
# Cycle 17 lasts 1:20:23 hours
# Cycle 18 lasts 2:32:58 hours
# Cycle 19 lasts 3:18:38 hours
# Cycle 20 lasts 2:43:10 hours
# Cycle 21 lasts 2:37:04 hours
# Cycle 22 lasts 2:19:28 hours
# Cycle 23 lasts 2:56:19 hours
# Cycle 24 lasts 3:10:06 hours
# Cycle 25 lasts 3:23:26 hours
# Cycle 26 lasts 2:51:15 hours
# Cycle 27 lasts 1:33:45 hours
# Cycle 28 lasts 2:58:49 hours
# Cycle 29 lasts 1:21:57 hours
# Cycle 30 lasts 2:03:49 hours
# Cycle 31 lasts 2:07:49 hours
# Cycle 32 lasts 1:59:51 hours
# Cycle 33 lasts 2:05:05 hours
# Cycle 34 lasts 1:25:39 hours
# Cycle 35 lasts 3:03:52 hours
# Cycle 36 lasts 2:30:34 hours
# Cycle 37 lasts 2:10:52 hours
# Cycle 38 lasts 1:57:16 hours
# Cycle 39 lasts 1:53:32 hours
# Cycle 40 lasts 3:07:04 hours
# Cycle 41 lasts 2:19:28 hours
# Cycle 42 lasts 2:45:25 hours
# Cycle 43 lasts 1:59:28 hours
# Cycle 44 lasts 2:58:49 hours
# Cycle 45 lasts 2:11:29 hours
# Cycle 46 lasts 2:33:59 hours
# Cycle 47 lasts 2:50:40 hours
# Cycle 48 lasts 2:35:16 hours
# Cycle 49 lasts 1:18:49 hours
# Cycle 50 lasts 2:08:38 hours
# Cycle 51 lasts 2:07:38 hours
# Cycle 52 lasts 2:12:58 hours
# Cycle 53 lasts 2:26:14 hours
# Cycle 54 lasts 2:03:55 hours
# Cycle 55 lasts 2:25:21 hours
# Cycle 56 lasts 1:58:54 hours
# Cycle 57 lasts 2:09:55 hours
# Cycle 58 lasts 1:59:28 hours
# Cycle 59 lasts 1:20:23 hours
# Cycle 60 lasts 2:10:32 hours
# Cycle 61 lasts 2:04:18 hours
# Cycle 62 lasts 2:57:45 hours
# Cycle 63 lasts 3:03:10 hours
# Cycle 64 lasts 2:51:12 hours
# Cycle 65 lasts 2:43:17 hours
# Cycle 66 lasts 2:48:59 hours
# Cycle 67 lasts 2:10:32 hours
# Cycle 68 lasts 3:09:15 hours
# Cycle 69 lasts 3:13:50 hours
# Cycle 70 lasts 2:51:10 hours
# Cycle 71 lasts 3:07:04 hours
# Cycle 72 lasts 1:20:23 hours
# Cycle 73 lasts 2:35:58 hours
#
# Min value is 4729, max_value is 12250
#
# Unit 3 has flight class: 2 (3-5 hours)
#
# Cycle 1 lasts 3:03:10 hours
# Cycle 2 lasts 2:48:02 hours
# Cycle 3 lasts 2:17:38 hours
# Cycle 4 lasts 2:19:28 hours
# Cycle 5 lasts 1:20:30 hours
# Cycle 6 lasts 1:55:45 hours
# Cycle 7 lasts 2:34:09 hours
# Cycle 8 lasts 1:06:15 hours
# Cycle 9 lasts 3:17:52 hours
# Cycle 10 lasts 2:37:04 hours
# Cycle 11 lasts 2:49:00 hours
# Cycle 12 lasts 2:36:59 hours
# Cycle 13 lasts 2:56:05 hours
# Cycle 14 lasts 1:47:38 hours
# Cycle 15 lasts 2:18:40 hours
# Cycle 16 lasts 2:09:42 hours
# Cycle 17 lasts 2:11:29 hours
# Cycle 18 lasts 2:35:58 hours
# Cycle 19 lasts 2:57:45 hours
# Cycle 20 lasts 2:34:09 hours
# Cycle 21 lasts 1:33:45 hours
# Cycle 22 lasts 3:17:52 hours
# Cycle 23 lasts 3:05:01 hours
# Cycle 24 lasts 2:30:34 hours
# Cycle 25 lasts 2:45:51 hours
# Cycle 26 lasts 2:07:38 hours
# Cycle 27 lasts 2:01:00 hours
# Cycle 28 lasts 2:35:58 hours
# Cycle 29 lasts 2:13:08 hours
# Cycle 30 lasts 2:01:25 hours
# Cycle 31 lasts 2:37:27 hours
# Cycle 32 lasts 2:43:34 hours
# Cycle 33 lasts 2:56:19 hours
# Cycle 34 lasts 2:33:59 hours
# Cycle 35 lasts 2:37:45 hours
# Cycle 36 lasts 2:04:46 hours
# Cycle 37 lasts 2:58:49 hours
# Cycle 38 lasts 1:34:56 hours
# Cycle 39 lasts 2:37:45 hours
# Cycle 40 lasts 2:13:08 hours
# Cycle 41 lasts 2:16:37 hours
# Cycle 42 lasts 3:17:53 hours
# Cycle 43 lasts 2:09:01 hours
# Cycle 44 lasts 2:55:37 hours
# Cycle 45 lasts 2:49:00 hours
# Cycle 46 lasts 2:01:00 hours
# Cycle 47 lasts 2:46:00 hours
# Cycle 48 lasts 2:18:13 hours
# Cycle 49 lasts 2:43:10 hours
# Cycle 50 lasts 2:57:45 hours
# Cycle 51 lasts 2:51:10 hours
# Cycle 52 lasts 1:25:39 hours
# Cycle 53 lasts 2:35:16 hours
# Cycle 54 lasts 2:45:25 hours
# Cycle 55 lasts 2:17:07 hours
# Cycle 56 lasts 2:09:55 hours
# Cycle 57 lasts 1:27:21 hours
# Cycle 58 lasts 3:24:55 hours
# Cycle 59 lasts 2:30:45 hours
# Cycle 60 lasts 2:33:59 hours
# Cycle 61 lasts 1:58:54 hours
# Cycle 62 lasts 1:56:49 hours
# Cycle 63 lasts 2:40:12 hours
# Cycle 64 lasts 1:56:10 hours
# Cycle 65 lasts 2:58:49 hours
# Cycle 66 lasts 2:30:45 hours
# Cycle 67 lasts 2:05:12 hours
#
# Min value is 3975, max_value is 12295
#
# Unit 4 has flight class: 2 (3-5 hours)
#
# Cycle 1 lasts 1:59:51 hours
# Cycle 2 lasts 1:56:10 hours
# Cycle 3 lasts 2:47:33 hours
# Cycle 4 lasts 2:19:28 hours
# Cycle 5 lasts 3:10:06 hours
# Cycle 6 lasts 2:14:14 hours
# Cycle 7 lasts 2:26:24 hours
# Cycle 8 lasts 2:45:25 hours
# Cycle 9 lasts 2:36:47 hours
# Cycle 10 lasts 2:04:18 hours
# Cycle 11 lasts 2:45:51 hours
# Cycle 12 lasts 2:47:49 hours
# Cycle 13 lasts 2:37:45 hours
# Cycle 14 lasts 1:37:33 hours
# Cycle 15 lasts 2:04:46 hours
# Cycle 16 lasts 2:25:21 hours
# Cycle 17 lasts 2:47:33 hours
# Cycle 18 lasts 2:28:47 hours
# Cycle 19 lasts 2:51:12 hours
# Cycle 20 lasts 2:26:57 hours
# Cycle 21 lasts 2:39:54 hours
# Cycle 22 lasts 2:40:12 hours
# Cycle 23 lasts 2:54:08 hours
# Cycle 24 lasts 2:48:02 hours
# Cycle 25 lasts 2:35:16 hours
# Cycle 26 lasts 1:59:51 hours
# Cycle 27 lasts 2:26:24 hours
# Cycle 28 lasts 2:24:00 hours
# Cycle 29 lasts 1:57:16 hours
# Cycle 30 lasts 3:08:43 hours
# Cycle 31 lasts 1:32:42 hours
# Cycle 32 lasts 3:04:28 hours
# Cycle 33 lasts 1:51:13 hours
# Cycle 34 lasts 2:10:06 hours
# Cycle 35 lasts 1:57:16 hours
# Cycle 36 lasts 2:10:06 hours
# Cycle 37 lasts 2:49:58 hours
# Cycle 38 lasts 2:43:17 hours
# Cycle 39 lasts 2:36:47 hours
# Cycle 40 lasts 2:30:34 hours
# Cycle 41 lasts 2:56:05 hours
# Cycle 42 lasts 2:26:49 hours
# Cycle 43 lasts 2:25:21 hours
# Cycle 44 lasts 2:36:47 hours
# Cycle 45 lasts 1:57:16 hours
# Cycle 46 lasts 2:32:58 hours
# Cycle 47 lasts 2:43:10 hours
# Cycle 48 lasts 3:17:53 hours
# Cycle 49 lasts 2:32:58 hours
# Cycle 50 lasts 2:26:24 hours
# Cycle 51 lasts 2:43:17 hours
# Cycle 52 lasts 2:07:38 hours
# Cycle 53 lasts 3:03:52 hours
# Cycle 54 lasts 2:32:35 hours
# Cycle 55 lasts 2:07:38 hours
# Cycle 56 lasts 3:01:56 hours
# Cycle 57 lasts 2:19:09 hours
# Cycle 58 lasts 2:34:09 hours
# Cycle 59 lasts 2:49:00 hours
# Cycle 60 lasts 2:15:49 hours
#
# Min value is 5562, max_value is 11873
#
# Unit 5 has flight class: 1 (1-3 hours)
#
# Cycle 1 lasts 1:09:41 hours
# Cycle 2 lasts 1:06:48 hours
# Cycle 3 lasts 1:25:30 hours
# Cycle 4 lasts 1:14:58 hours
# Cycle 5 lasts 1:09:41 hours
# Cycle 6 lasts 1:09:41 hours
# Cycle 7 lasts 1:17:40 hours
# Cycle 8 lasts 0:55:36 hours
# Cycle 9 lasts 1:02:30 hours
# Cycle 10 lasts 0:55:36 hours
# Cycle 11 lasts 1:14:22 hours
# Cycle 12 lasts 0:58:24 hours
# Cycle 13 lasts 0:58:24 hours
# Cycle 14 lasts 1:02:30 hours
# Cycle 15 lasts 0:55:36 hours
# Cycle 16 lasts 0:52:01 hours
# Cycle 17 lasts 1:34:37 hours
# Cycle 18 lasts 0:58:24 hours
# Cycle 19 lasts 1:29:38 hours
# Cycle 20 lasts 1:14:22 hours
# Cycle 21 lasts 1:14:55 hours
# Cycle 22 lasts 1:03:16 hours
# Cycle 23 lasts 1:29:15 hours
# Cycle 24 lasts 1:14:58 hours
# Cycle 25 lasts 0:52:01 hours
# Cycle 26 lasts 0:52:01 hours
# Cycle 27 lasts 1:34:37 hours
# Cycle 28 lasts 1:03:34 hours
# Cycle 29 lasts 1:03:34 hours
# Cycle 30 lasts 1:03:16 hours
# Cycle 31 lasts 0:58:24 hours
# Cycle 32 lasts 1:03:16 hours
# Cycle 33 lasts 1:03:16 hours
# Cycle 34 lasts 0:58:24 hours
# Cycle 35 lasts 1:09:41 hours
# Cycle 36 lasts 1:09:41 hours
# Cycle 37 lasts 1:29:15 hours
# Cycle 38 lasts 0:55:36 hours
# Cycle 39 lasts 1:29:15 hours
# Cycle 40 lasts 1:22:38 hours
# Cycle 41 lasts 1:14:22 hours
# Cycle 42 lasts 1:14:58 hours
# Cycle 43 lasts 1:14:58 hours
# Cycle 44 lasts 1:14:58 hours
# Cycle 45 lasts 1:03:34 hours
# Cycle 46 lasts 1:03:16 hours
# Cycle 47 lasts 0:52:01 hours
# Cycle 48 lasts 1:09:41 hours
# Cycle 49 lasts 1:14:55 hours
# Cycle 50 lasts 1:29:15 hours
# Cycle 51 lasts 1:24:29 hours
# Cycle 52 lasts 1:25:30 hours
# Cycle 53 lasts 0:58:24 hours
# Cycle 54 lasts 0:55:36 hours
# Cycle 55 lasts 1:29:38 hours
# Cycle 56 lasts 1:34:37 hours
# Cycle 57 lasts 1:03:16 hours
# Cycle 58 lasts 1:06:48 hours
# Cycle 59 lasts 1:24:29 hours
# Cycle 60 lasts 1:02:30 hours
# Cycle 61 lasts 1:06:48 hours
# Cycle 62 lasts 0:58:24 hours
# Cycle 63 lasts 0:55:36 hours
# Cycle 64 lasts 1:14:55 hours
# Cycle 65 lasts 1:14:58 hours
# Cycle 66 lasts 1:17:40 hours
# Cycle 67 lasts 1:06:48 hours
# Cycle 68 lasts 1:29:38 hours
# Cycle 69 lasts 0:55:36 hours
# Cycle 70 lasts 1:34:37 hours
# Cycle 71 lasts 1:06:48 hours
# Cycle 72 lasts 1:29:38 hours
# Cycle 73 lasts 1:14:58 hours
# Cycle 74 lasts 1:14:55 hours
# Cycle 75 lasts 1:14:22 hours
# Cycle 76 lasts 1:14:22 hours
# Cycle 77 lasts 1:22:38 hours
# Cycle 78 lasts 1:17:40 hours
# Cycle 79 lasts 1:14:22 hours
# Cycle 80 lasts 1:14:58 hours
# Cycle 81 lasts 1:09:41 hours
# Cycle 82 lasts 1:14:58 hours
# Cycle 83 lasts 0:58:24 hours
# Cycle 84 lasts 1:14:58 hours
# Cycle 85 lasts 1:17:40 hours
# Cycle 86 lasts 1:29:15 hours
# Cycle 87 lasts 1:09:41 hours
# Cycle 88 lasts 1:24:29 hours
# Cycle 89 lasts 1:34:37 hours
# Cycle 90 lasts 1:06:48 hours
# Cycle 91 lasts 1:29:38 hours
# Cycle 92 lasts 1:06:48 hours
# Cycle 93 lasts 1:14:58 hours
#
# Min value is 3121, max_value is 5677
#
# Unit 6 has flight class: 3 (5-7 hours)
#
# Cycle 1 lasts 5:37:23 hours
# Cycle 2 lasts 3:34:46 hours
# Cycle 3 lasts 4:41:12 hours
# Cycle 4 lasts 2:47:09 hours
# Cycle 5 lasts 4:42:10 hours
# Cycle 6 lasts 5:37:23 hours
# Cycle 7 lasts 5:25:20 hours
# Cycle 8 lasts 3:40:29 hours
# Cycle 9 lasts 4:50:13 hours
# Cycle 10 lasts 4:11:13 hours
# Cycle 11 lasts 4:42:10 hours
# Cycle 12 lasts 3:47:55 hours
# Cycle 13 lasts 3:18:33 hours
# Cycle 14 lasts 4:41:06 hours
# Cycle 15 lasts 4:49:59 hours
# Cycle 16 lasts 4:50:13 hours
# Cycle 17 lasts 3:18:43 hours
# Cycle 18 lasts 4:18:26 hours
# Cycle 19 lasts 4:41:31 hours
# Cycle 20 lasts 4:22:52 hours
# Cycle 21 lasts 3:44:46 hours
# Cycle 22 lasts 4:30:32 hours
# Cycle 23 lasts 4:01:38 hours
# Cycle 24 lasts 3:04:28 hours
# Cycle 25 lasts 3:05:33 hours
# Cycle 26 lasts 3:23:06 hours
# Cycle 27 lasts 3:53:05 hours
# Cycle 28 lasts 4:23:35 hours
# Cycle 29 lasts 5:37:23 hours
# Cycle 30 lasts 3:28:37 hours
# Cycle 31 lasts 5:14:05 hours
# Cycle 32 lasts 5:14:05 hours
# Cycle 33 lasts 4:18:26 hours
# Cycle 34 lasts 3:47:59 hours
# Cycle 35 lasts 4:16:52 hours
# Cycle 36 lasts 4:55:30 hours
# Cycle 37 lasts 3:47:55 hours
# Cycle 38 lasts 4:21:14 hours
# Cycle 39 lasts 3:47:09 hours
# Cycle 40 lasts 2:58:46 hours
# Cycle 41 lasts 4:23:35 hours
# Cycle 42 lasts 4:18:26 hours
# Cycle 43 lasts 3:58:18 hours
# Cycle 44 lasts 3:34:46 hours
# Cycle 45 lasts 2:58:28 hours
# Cycle 46 lasts 4:35:03 hours
# Cycle 47 lasts 3:34:46 hours
# Cycle 48 lasts 4:40:14 hours
# Cycle 49 lasts 4:04:40 hours
# Cycle 50 lasts 5:37:23 hours
# Cycle 51 lasts 4:29:29 hours
# Cycle 52 lasts 3:47:09 hours
# Cycle 53 lasts 3:19:26 hours
# Cycle 54 lasts 4:41:31 hours
# Cycle 55 lasts 4:26:38 hours
# Cycle 56 lasts 4:40:48 hours
# Cycle 57 lasts 2:46:15 hours
# Cycle 58 lasts 4:40:48 hours
# Cycle 59 lasts 2:52:20 hours
# Cycle 60 lasts 3:04:28 hours
# Cycle 61 lasts 3:30:21 hours
# Cycle 62 lasts 3:18:33 hours
# Cycle 63 lasts 5:38:14 hours
#
# Min value is 9975, max_value is 20294
#
# Unit 7 has flight class: 2 (3-5 hours)
#
# Cycle 1 lasts 2:34:57 hours
# Cycle 2 lasts 2:17:38 hours
# Cycle 3 lasts 2:51:10 hours
# Cycle 4 lasts 1:18:49 hours
# Cycle 5 lasts 3:13:23 hours
# Cycle 6 lasts 2:28:14 hours
# Cycle 7 lasts 2:22:22 hours
# Cycle 8 lasts 2:55:59 hours
# Cycle 9 lasts 2:47:49 hours
# Cycle 10 lasts 2:49:00 hours
# Cycle 11 lasts 1:18:23 hours
# Cycle 12 lasts 2:18:13 hours
# Cycle 13 lasts 2:36:44 hours
# Cycle 14 lasts 3:03:32 hours
# Cycle 15 lasts 2:15:37 hours
# Cycle 16 lasts 3:09:31 hours
# Cycle 17 lasts 2:09:42 hours
# Cycle 18 lasts 3:09:31 hours
# Cycle 19 lasts 2:09:55 hours
# Cycle 20 lasts 3:01:56 hours
# Cycle 21 lasts 2:47:49 hours
# Cycle 22 lasts 3:18:38 hours
# Cycle 23 lasts 2:26:14 hours
# Cycle 24 lasts 2:56:19 hours
# Cycle 25 lasts 1:51:13 hours
# Cycle 26 lasts 2:21:24 hours
# Cycle 27 lasts 2:49:58 hours
# Cycle 28 lasts 2:45:20 hours
# Cycle 29 lasts 2:07:58 hours
# Cycle 30 lasts 2:18:00 hours
# Cycle 31 lasts 1:20:23 hours
# Cycle 32 lasts 1:42:00 hours
# Cycle 33 lasts 2:09:55 hours
# Cycle 34 lasts 2:18:40 hours
# Cycle 35 lasts 2:07:58 hours
# Cycle 36 lasts 2:12:20 hours
# Cycle 37 lasts 2:44:50 hours
# Cycle 38 lasts 2:39:54 hours
# Cycle 39 lasts 2:28:14 hours
# Cycle 40 lasts 2:58:29 hours
# Cycle 41 lasts 2:34:28 hours
# Cycle 42 lasts 2:54:08 hours
# Cycle 43 lasts 1:18:23 hours
# Cycle 44 lasts 2:28:20 hours
# Cycle 45 lasts 2:09:42 hours
# Cycle 46 lasts 2:12:18 hours
# Cycle 47 lasts 2:22:14 hours
# Cycle 48 lasts 3:09:15 hours
# Cycle 49 lasts 2:03:49 hours
# Cycle 50 lasts 1:58:54 hours
# Cycle 51 lasts 2:18:40 hours
# Cycle 52 lasts 3:13:50 hours
# Cycle 53 lasts 1:37:33 hours
# Cycle 54 lasts 1:21:57 hours
# Cycle 55 lasts 3:13:23 hours
# Cycle 56 lasts 2:51:12 hours
# Cycle 57 lasts 1:57:16 hours
# Cycle 58 lasts 2:36:59 hours
# Cycle 59 lasts 3:09:17 hours
# Cycle 60 lasts 2:26:57 hours
# Cycle 61 lasts 2:32:58 hours
# Cycle 62 lasts 2:58:04 hours
# Cycle 63 lasts 2:37:27 hours
# Cycle 64 lasts 2:21:21 hours
# Cycle 65 lasts 2:12:20 hours
# Cycle 66 lasts 1:57:14 hours
# Cycle 67 lasts 1:57:16 hours
# Cycle 68 lasts 1:58:21 hours
# Cycle 69 lasts 3:04:28 hours
# Cycle 70 lasts 2:32:58 hours
# Cycle 71 lasts 2:45:20 hours
# Cycle 72 lasts 1:52:16 hours
# Cycle 73 lasts 1:58:21 hours
# Cycle 74 lasts 2:18:00 hours
# Cycle 75 lasts 2:12:58 hours
# Cycle 76 lasts 2:18:13 hours
# Cycle 77 lasts 2:50:40 hours
# Cycle 78 lasts 2:30:34 hours
# Cycle 79 lasts 1:34:56 hours
# Cycle 80 lasts 2:33:59 hours
#
# Min value is 4703, max_value is 11918
#
# Unit 8 has flight class: 3 (5-7 hours)
#
# Cycle 1 lasts 4:41:06 hours
# Cycle 2 lasts 5:14:05 hours
# Cycle 3 lasts 4:00:20 hours
# Cycle 4 lasts 4:41:06 hours
# Cycle 5 lasts 4:41:14 hours
# Cycle 6 lasts 4:16:52 hours
# Cycle 7 lasts 3:55:26 hours
# Cycle 8 lasts 3:37:29 hours
# Cycle 9 lasts 3:37:29 hours
# Cycle 10 lasts 4:48:28 hours
# Cycle 11 lasts 3:04:28 hours
# Cycle 12 lasts 4:09:14 hours
# Cycle 13 lasts 3:05:33 hours
# Cycle 14 lasts 4:15:30 hours
# Cycle 15 lasts 4:41:06 hours
# Cycle 16 lasts 3:53:05 hours
# Cycle 17 lasts 3:04:30 hours
# Cycle 18 lasts 5:30:45 hours
# Cycle 19 lasts 4:08:22 hours
# Cycle 20 lasts 4:15:41 hours
# Cycle 21 lasts 4:15:41 hours
# Cycle 22 lasts 4:33:48 hours
# Cycle 23 lasts 5:30:45 hours
# Cycle 24 lasts 4:10:53 hours
# Cycle 25 lasts 3:05:39 hours
# Cycle 26 lasts 3:40:29 hours
# Cycle 27 lasts 3:58:18 hours
# Cycle 28 lasts 3:05:33 hours
# Cycle 29 lasts 3:14:37 hours
# Cycle 30 lasts 4:06:01 hours
# Cycle 31 lasts 5:28:14 hours
# Cycle 32 lasts 4:30:32 hours
# Cycle 33 lasts 3:48:50 hours
# Cycle 34 lasts 2:58:46 hours
# Cycle 35 lasts 4:12:33 hours
# Cycle 36 lasts 4:29:29 hours
# Cycle 37 lasts 3:37:29 hours
# Cycle 38 lasts 3:27:02 hours
# Cycle 39 lasts 4:55:30 hours
# Cycle 40 lasts 3:28:37 hours
# Cycle 41 lasts 4:30:32 hours
# Cycle 42 lasts 4:49:17 hours
# Cycle 43 lasts 4:41:31 hours
# Cycle 44 lasts 4:04:10 hours
# Cycle 45 lasts 4:33:48 hours
# Cycle 46 lasts 3:07:31 hours
# Cycle 47 lasts 4:25:11 hours
# Cycle 48 lasts 5:30:45 hours
# Cycle 49 lasts 3:44:46 hours
# Cycle 50 lasts 4:31:25 hours
# Cycle 51 lasts 3:05:39 hours
# Cycle 52 lasts 4:26:05 hours
# Cycle 53 lasts 4:32:02 hours
# Cycle 54 lasts 3:47:48 hours
# Cycle 55 lasts 4:27:31 hours
# Cycle 56 lasts 2:28:46 hours
# Cycle 57 lasts 4:41:14 hours
# Cycle 58 lasts 4:26:39 hours
# Cycle 59 lasts 4:01:38 hours
# Cycle 60 lasts 4:26:38 hours
# Cycle 61 lasts 4:04:10 hours
# Cycle 62 lasts 4:38:46 hours
# Cycle 63 lasts 5:14:05 hours
# Cycle 64 lasts 4:41:14 hours
# Cycle 65 lasts 4:49:17 hours
# Cycle 66 lasts 4:31:25 hours
# Cycle 67 lasts 4:36:10 hours
# Cycle 68 lasts 4:13:23 hours
# Cycle 69 lasts 4:41:31 hours
# Cycle 70 lasts 3:59:39 hours
# Cycle 71 lasts 4:23:35 hours
#
# Min value is 8926, max_value is 19845
#
# Unit 9 has flight class: 1 (1-3 hours)
#
# Cycle 1 lasts 1:02:30 hours
# Cycle 2 lasts 1:22:38 hours
# Cycle 3 lasts 1:25:30 hours
# Cycle 4 lasts 1:22:38 hours
# Cycle 5 lasts 1:06:48 hours
# Cycle 6 lasts 1:17:40 hours
# Cycle 7 lasts 1:29:38 hours
# Cycle 8 lasts 1:14:22 hours
# Cycle 9 lasts 1:14:22 hours
# Cycle 10 lasts 1:24:29 hours
# Cycle 11 lasts 1:14:58 hours
# Cycle 12 lasts 1:14:55 hours
# Cycle 13 lasts 1:09:41 hours
# Cycle 14 lasts 1:22:38 hours
# Cycle 15 lasts 1:25:30 hours
# Cycle 16 lasts 0:58:24 hours
# Cycle 17 lasts 1:09:41 hours
# Cycle 18 lasts 1:03:34 hours
# Cycle 19 lasts 1:02:30 hours
# Cycle 20 lasts 1:02:30 hours
# Cycle 21 lasts 1:24:29 hours
# Cycle 22 lasts 1:09:41 hours
# Cycle 23 lasts 1:14:22 hours
# Cycle 24 lasts 1:14:55 hours
# Cycle 25 lasts 0:58:24 hours
# Cycle 26 lasts 1:03:16 hours
# Cycle 27 lasts 1:14:58 hours
# Cycle 28 lasts 1:09:41 hours
# Cycle 29 lasts 1:25:30 hours
# Cycle 30 lasts 1:29:38 hours
# Cycle 31 lasts 1:34:37 hours
# Cycle 32 lasts 1:34:37 hours
# Cycle 33 lasts 1:06:48 hours
# Cycle 34 lasts 0:52:01 hours
# Cycle 35 lasts 0:58:24 hours
# Cycle 36 lasts 1:25:30 hours
# Cycle 37 lasts 1:22:38 hours
# Cycle 38 lasts 1:29:38 hours
# Cycle 39 lasts 1:29:15 hours
# Cycle 40 lasts 1:17:40 hours
# Cycle 41 lasts 1:14:58 hours
# Cycle 42 lasts 1:25:30 hours
# Cycle 43 lasts 1:03:16 hours
# Cycle 44 lasts 0:52:01 hours
# Cycle 45 lasts 1:29:15 hours
# Cycle 46 lasts 0:52:01 hours
# Cycle 47 lasts 1:09:41 hours
# Cycle 48 lasts 1:17:40 hours
# Cycle 49 lasts 0:58:24 hours
# Cycle 50 lasts 0:55:36 hours
# Cycle 51 lasts 1:06:48 hours
# Cycle 52 lasts 1:02:30 hours
# Cycle 53 lasts 1:03:16 hours
# Cycle 54 lasts 1:14:58 hours
# Cycle 55 lasts 1:34:37 hours
# Cycle 56 lasts 0:55:36 hours
# Cycle 57 lasts 0:55:36 hours
# Cycle 58 lasts 0:55:36 hours
# Cycle 59 lasts 0:58:24 hours
# Cycle 60 lasts 1:29:38 hours
# Cycle 61 lasts 0:52:01 hours
# Cycle 62 lasts 1:03:34 hours
# Cycle 63 lasts 1:14:22 hours
# Cycle 64 lasts 1:06:48 hours
# Cycle 65 lasts 1:14:22 hours
# Cycle 66 lasts 1:29:15 hours
# Cycle 67 lasts 1:17:40 hours
# Cycle 68 lasts 1:02:30 hours
# Cycle 69 lasts 1:02:30 hours
# Cycle 70 lasts 0:52:01 hours
# Cycle 71 lasts 1:14:55 hours
# Cycle 72 lasts 1:14:22 hours
# Cycle 73 lasts 0:52:01 hours
# Cycle 74 lasts 1:03:34 hours
# Cycle 75 lasts 0:55:36 hours
# Cycle 76 lasts 1:25:30 hours
# Cycle 77 lasts 1:03:16 hours
# Cycle 78 lasts 1:22:38 hours
# Cycle 79 lasts 0:58:24 hours
# Cycle 80 lasts 1:14:22 hours
# Cycle 81 lasts 1:34:37 hours
# Cycle 82 lasts 1:14:55 hours
# Cycle 83 lasts 1:14:55 hours
# Cycle 84 lasts 1:29:15 hours
#
# Min value is 3121, max_value is 5677
#
# Unit 10 has flight class: 3 (5-7 hours)
#
# Cycle 1 lasts 4:37:33 hours
# Cycle 2 lasts 4:55:30 hours
# Cycle 3 lasts 4:27:31 hours
# Cycle 4 lasts 4:01:12 hours
# Cycle 5 lasts 3:48:00 hours
# Cycle 6 lasts 4:29:29 hours
# Cycle 7 lasts 4:41:12 hours
# Cycle 8 lasts 3:41:22 hours
# Cycle 9 lasts 3:40:29 hours
# Cycle 10 lasts 3:38:05 hours
# Cycle 11 lasts 4:48:10 hours
# Cycle 12 lasts 3:56:25 hours
# Cycle 13 lasts 3:50:17 hours
# Cycle 14 lasts 4:41:12 hours
# Cycle 15 lasts 3:52:06 hours
# Cycle 16 lasts 2:40:49 hours
# Cycle 17 lasts 3:34:46 hours
# Cycle 18 lasts 4:05:41 hours
# Cycle 19 lasts 2:47:09 hours
# Cycle 20 lasts 3:59:17 hours
# Cycle 21 lasts 3:37:54 hours
# Cycle 22 lasts 3:14:37 hours
# Cycle 23 lasts 4:10:53 hours
# Cycle 24 lasts 4:32:02 hours
# Cycle 25 lasts 3:38:05 hours
# Cycle 26 lasts 3:52:06 hours
# Cycle 27 lasts 3:07:31 hours
# Cycle 28 lasts 4:09:37 hours
# Cycle 29 lasts 3:07:20 hours
# Cycle 30 lasts 4:10:53 hours
# Cycle 31 lasts 5:37:39 hours
# Cycle 32 lasts 3:55:34 hours
# Cycle 33 lasts 3:21:06 hours
# Cycle 34 lasts 4:41:12 hours
# Cycle 35 lasts 4:06:40 hours
# Cycle 36 lasts 4:11:13 hours
# Cycle 37 lasts 2:40:49 hours
# Cycle 38 lasts 4:33:48 hours
# Cycle 39 lasts 3:47:55 hours
# Cycle 40 lasts 4:20:35 hours
# Cycle 41 lasts 4:09:14 hours
# Cycle 42 lasts 4:59:09 hours
# Cycle 43 lasts 4:08:22 hours
# Cycle 44 lasts 4:50:13 hours
# Cycle 45 lasts 3:05:33 hours
# Cycle 46 lasts 3:48:00 hours
# Cycle 47 lasts 4:04:10 hours
# Cycle 48 lasts 3:19:37 hours
# Cycle 49 lasts 4:26:38 hours
# Cycle 50 lasts 4:49:24 hours
# Cycle 51 lasts 2:47:09 hours
# Cycle 52 lasts 3:47:48 hours
# Cycle 53 lasts 3:47:48 hours
# Cycle 54 lasts 4:37:33 hours
# Cycle 55 lasts 3:48:50 hours
# Cycle 56 lasts 4:40:14 hours
# Cycle 57 lasts 4:09:14 hours
# Cycle 58 lasts 4:09:14 hours
# Cycle 59 lasts 3:47:48 hours
# Cycle 60 lasts 5:29:53 hours
# Cycle 61 lasts 3:18:43 hours
# Cycle 62 lasts 4:15:30 hours
# Cycle 63 lasts 2:54:05 hours
# Cycle 64 lasts 4:31:25 hours
# Cycle 65 lasts 3:43:54 hours
# Cycle 66 lasts 3:28:37 hours
#
# Min value is 9649, max_value is 20259
#
# Unit 11 has flight class: 3 (5-7 hours)
#
# Cycle 1 lasts 3:37:13 hours
# Cycle 2 lasts 5:38:14 hours
# Cycle 3 lasts 3:53:05 hours
# Cycle 4 lasts 4:19:08 hours
# Cycle 5 lasts 4:22:56 hours
# Cycle 6 lasts 4:11:13 hours
# Cycle 7 lasts 3:37:13 hours
# Cycle 8 lasts 3:04:28 hours
# Cycle 9 lasts 3:19:26 hours
# Cycle 10 lasts 4:26:38 hours
# Cycle 11 lasts 4:22:56 hours
# Cycle 12 lasts 4:31:25 hours
# Cycle 13 lasts 3:37:54 hours
# Cycle 14 lasts 4:01:12 hours
# Cycle 15 lasts 3:18:43 hours
# Cycle 16 lasts 3:55:34 hours
# Cycle 17 lasts 3:55:34 hours
# Cycle 18 lasts 4:20:35 hours
# Cycle 19 lasts 3:06:14 hours
# Cycle 20 lasts 2:28:46 hours
# Cycle 21 lasts 4:09:37 hours
# Cycle 22 lasts 2:54:05 hours
# Cycle 23 lasts 3:37:13 hours
# Cycle 24 lasts 3:55:26 hours
# Cycle 25 lasts 3:34:46 hours
# Cycle 26 lasts 2:58:28 hours
# Cycle 27 lasts 4:11:18 hours
# Cycle 28 lasts 3:48:00 hours
# Cycle 29 lasts 3:47:59 hours
# Cycle 30 lasts 3:44:46 hours
# Cycle 31 lasts 2:58:28 hours
# Cycle 32 lasts 4:41:06 hours
# Cycle 33 lasts 3:38:05 hours
# Cycle 34 lasts 3:53:36 hours
# Cycle 35 lasts 3:21:06 hours
# Cycle 36 lasts 3:55:01 hours
# Cycle 37 lasts 3:21:06 hours
# Cycle 38 lasts 3:14:37 hours
# Cycle 39 lasts 4:04:40 hours
# Cycle 40 lasts 3:50:17 hours
# Cycle 41 lasts 3:37:12 hours
# Cycle 42 lasts 3:45:16 hours
# Cycle 43 lasts 4:48:28 hours
# Cycle 44 lasts 3:34:46 hours
# Cycle 45 lasts 4:23:35 hours
# Cycle 46 lasts 4:40:14 hours
# Cycle 47 lasts 3:53:36 hours
# Cycle 48 lasts 4:40:48 hours
# Cycle 49 lasts 4:33:48 hours
# Cycle 50 lasts 4:00:20 hours
# Cycle 51 lasts 4:30:32 hours
# Cycle 52 lasts 2:54:05 hours
# Cycle 53 lasts 4:41:31 hours
# Cycle 54 lasts 3:31:41 hours
# Cycle 55 lasts 4:20:35 hours
# Cycle 56 lasts 3:28:37 hours
# Cycle 57 lasts 3:26:08 hours
# Cycle 58 lasts 5:29:53 hours
# Cycle 59 lasts 2:52:20 hours
#
# Min value is 8926, max_value is 20294
#
# Unit 12 has flight class: 1 (1-3 hours)
#
# Cycle 1 lasts 1:09:41 hours
# Cycle 2 lasts 1:25:30 hours
# Cycle 3 lasts 1:06:48 hours
# Cycle 4 lasts 1:24:29 hours
# Cycle 5 lasts 0:55:36 hours
# Cycle 6 lasts 0:52:01 hours
# Cycle 7 lasts 0:52:01 hours
# Cycle 8 lasts 1:03:16 hours
# Cycle 9 lasts 1:25:30 hours
# Cycle 10 lasts 0:55:36 hours
# Cycle 11 lasts 1:29:38 hours
# Cycle 12 lasts 1:34:37 hours
# Cycle 13 lasts 1:03:16 hours
# Cycle 14 lasts 1:22:38 hours
# Cycle 15 lasts 1:03:34 hours
# Cycle 16 lasts 1:09:41 hours
# Cycle 17 lasts 1:03:16 hours
# Cycle 18 lasts 1:29:38 hours
# Cycle 19 lasts 1:14:55 hours
# Cycle 20 lasts 1:17:40 hours
# Cycle 21 lasts 1:14:22 hours
# Cycle 22 lasts 1:14:55 hours
# Cycle 23 lasts 0:52:01 hours
# Cycle 24 lasts 1:09:41 hours
# Cycle 25 lasts 1:14:55 hours
# Cycle 26 lasts 0:55:36 hours
# Cycle 27 lasts 1:14:58 hours
# Cycle 28 lasts 1:25:30 hours
# Cycle 29 lasts 1:22:38 hours
# Cycle 30 lasts 0:55:36 hours
# Cycle 31 lasts 1:29:38 hours
# Cycle 32 lasts 1:22:38 hours
# Cycle 33 lasts 1:03:16 hours
# Cycle 34 lasts 1:09:41 hours
# Cycle 35 lasts 1:22:38 hours
# Cycle 36 lasts 1:03:16 hours
# Cycle 37 lasts 1:22:38 hours
# Cycle 38 lasts 1:14:58 hours
# Cycle 39 lasts 1:29:38 hours
# Cycle 40 lasts 1:29:15 hours
# Cycle 41 lasts 1:22:38 hours
# Cycle 42 lasts 0:52:01 hours
# Cycle 43 lasts 1:24:29 hours
# Cycle 44 lasts 1:25:30 hours
# Cycle 45 lasts 1:14:55 hours
# Cycle 46 lasts 0:52:01 hours
# Cycle 47 lasts 1:14:58 hours
# Cycle 48 lasts 1:14:58 hours
# Cycle 49 lasts 0:52:01 hours
# Cycle 50 lasts 1:29:38 hours
# Cycle 51 lasts 1:24:29 hours
# Cycle 52 lasts 1:25:30 hours
# Cycle 53 lasts 0:55:36 hours
# Cycle 54 lasts 1:25:30 hours
# Cycle 55 lasts 0:52:01 hours
# Cycle 56 lasts 1:34:37 hours
# Cycle 57 lasts 1:03:16 hours
# Cycle 58 lasts 1:14:55 hours
# Cycle 59 lasts 1:09:41 hours
# Cycle 60 lasts 1:25:30 hours
# Cycle 61 lasts 0:55:36 hours
# Cycle 62 lasts 1:22:38 hours
# Cycle 63 lasts 1:06:48 hours
# Cycle 64 lasts 0:55:36 hours
# Cycle 65 lasts 0:55:36 hours
# Cycle 66 lasts 1:14:22 hours
# Cycle 67 lasts 1:02:30 hours
# Cycle 68 lasts 1:17:40 hours
# Cycle 69 lasts 0:55:36 hours
# Cycle 70 lasts 1:17:40 hours
# Cycle 71 lasts 0:52:01 hours
# Cycle 72 lasts 1:17:40 hours
# Cycle 73 lasts 1:09:41 hours
# Cycle 74 lasts 0:52:01 hours
# Cycle 75 lasts 1:14:55 hours
# Cycle 76 lasts 1:24:29 hours
# Cycle 77 lasts 1:14:22 hours
# Cycle 78 lasts 1:03:34 hours
# Cycle 79 lasts 1:03:16 hours
# Cycle 80 lasts 1:29:15 hours
# Cycle 81 lasts 1:14:22 hours
# Cycle 82 lasts 1:02:30 hours
# Cycle 83 lasts 1:14:55 hours
# Cycle 84 lasts 1:29:38 hours
# Cycle 85 lasts 1:14:55 hours
# Cycle 86 lasts 1:03:34 hours
# Cycle 87 lasts 1:34:37 hours
# Cycle 88 lasts 1:17:40 hours
# Cycle 89 lasts 1:02:30 hours
# Cycle 90 lasts 0:55:36 hours
# Cycle 91 lasts 1:22:38 hours
# Cycle 92 lasts 1:22:38 hours
# Cycle 93 lasts 1:34:37 hours
#
# Min value is 3121, max_value is 5677
#
# Unit 13 has flight class: 3 (5-7 hours)
#
# Cycle 1 lasts 4:11:18 hours
# Cycle 2 lasts 4:06:01 hours
# Cycle 3 lasts 3:45:16 hours
# Cycle 4 lasts 3:59:39 hours
# Cycle 5 lasts 2:51:28 hours
# Cycle 6 lasts 3:27:02 hours
# Cycle 7 lasts 4:50:13 hours
# Cycle 8 lasts 2:28:46 hours
# Cycle 9 lasts 4:13:37 hours
# Cycle 10 lasts 4:49:59 hours
# Cycle 11 lasts 3:31:41 hours
# Cycle 12 lasts 4:13:23 hours
# Cycle 13 lasts 3:55:26 hours
# Cycle 14 lasts 3:55:26 hours
# Cycle 15 lasts 2:33:06 hours
# Cycle 16 lasts 5:12:06 hours
# Cycle 17 lasts 3:13:56 hours
# Cycle 18 lasts 4:36:10 hours
# Cycle 19 lasts 2:58:46 hours
# Cycle 20 lasts 3:58:18 hours
# Cycle 21 lasts 3:05:39 hours
# Cycle 22 lasts 5:08:04 hours
# Cycle 23 lasts 3:50:43 hours
# Cycle 24 lasts 4:49:17 hours
# Cycle 25 lasts 4:49:24 hours
# Cycle 26 lasts 4:04:40 hours
# Cycle 27 lasts 4:36:10 hours
# Cycle 28 lasts 3:21:06 hours
# Cycle 29 lasts 3:34:46 hours
# Cycle 30 lasts 3:40:45 hours
# Cycle 31 lasts 4:05:41 hours
# Cycle 32 lasts 2:46:15 hours
# Cycle 33 lasts 3:30:21 hours
# Cycle 34 lasts 4:59:09 hours
# Cycle 35 lasts 4:30:32 hours
# Cycle 36 lasts 4:22:56 hours
# Cycle 37 lasts 4:35:45 hours
# Cycle 38 lasts 4:30:32 hours
# Cycle 39 lasts 3:45:16 hours
# Cycle 40 lasts 4:11:18 hours
# Cycle 41 lasts 3:58:18 hours
# Cycle 42 lasts 4:07:57 hours
# Cycle 43 lasts 3:40:45 hours
# Cycle 44 lasts 4:23:35 hours
# Cycle 45 lasts 4:13:23 hours
# Cycle 46 lasts 4:26:38 hours
# Cycle 47 lasts 3:27:02 hours
# Cycle 48 lasts 4:33:48 hours
# Cycle 49 lasts 4:11:18 hours
# Cycle 50 lasts 4:15:30 hours
# Cycle 51 lasts 4:40:14 hours
# Cycle 52 lasts 3:34:46 hours
# Cycle 53 lasts 4:31:25 hours
# Cycle 54 lasts 3:40:29 hours
# Cycle 55 lasts 4:49:17 hours
# Cycle 56 lasts 3:05:39 hours
# Cycle 57 lasts 5:10:02 hours
# Cycle 58 lasts 4:08:22 hours
# Cycle 59 lasts 3:07:20 hours
# Cycle 60 lasts 2:46:15 hours
# Cycle 61 lasts 2:51:28 hours
# Cycle 62 lasts 4:19:08 hours
# Cycle 63 lasts 4:59:09 hours
# Cycle 64 lasts 2:28:46 hours
# Cycle 65 lasts 4:40:14 hours
# Cycle 66 lasts 3:14:37 hours
# Cycle 67 lasts 3:59:39 hours
# Cycle 68 lasts 3:07:20 hours
# Cycle 69 lasts 4:48:28 hours
# Cycle 70 lasts 4:05:41 hours
# Cycle 71 lasts 4:50:13 hours
# Cycle 72 lasts 3:58:18 hours
# Cycle 73 lasts 4:15:41 hours
# Cycle 74 lasts 3:52:06 hours
# Cycle 75 lasts 4:06:40 hours
# Cycle 76 lasts 2:58:46 hours
# Cycle 77 lasts 4:49:59 hours
#
# Min value is 8926, max_value is 18726
#
# Unit 14 has flight class: 1 (1-3 hours)
#
# Cycle 1 lasts 1:14:58 hours
# Cycle 2 lasts 0:55:36 hours
# Cycle 3 lasts 1:25:30 hours
# Cycle 4 lasts 1:03:34 hours
# Cycle 5 lasts 1:24:29 hours
# Cycle 6 lasts 1:17:40 hours
# Cycle 7 lasts 1:03:34 hours
# Cycle 8 lasts 1:14:58 hours
# Cycle 9 lasts 1:29:15 hours
# Cycle 10 lasts 1:29:15 hours
# Cycle 11 lasts 1:14:22 hours
# Cycle 12 lasts 1:24:29 hours
# Cycle 13 lasts 1:03:34 hours
# Cycle 14 lasts 1:14:55 hours
# Cycle 15 lasts 1:22:38 hours
# Cycle 16 lasts 0:55:36 hours
# Cycle 17 lasts 1:24:29 hours
# Cycle 18 lasts 1:14:55 hours
# Cycle 19 lasts 1:29:15 hours
# Cycle 20 lasts 1:14:55 hours
# Cycle 21 lasts 1:29:15 hours
# Cycle 22 lasts 1:25:30 hours
# Cycle 23 lasts 1:14:55 hours
# Cycle 24 lasts 1:24:29 hours
# Cycle 25 lasts 1:14:58 hours
# Cycle 26 lasts 1:29:38 hours
# Cycle 27 lasts 1:25:30 hours
# Cycle 28 lasts 1:14:55 hours
# Cycle 29 lasts 1:25:30 hours
# Cycle 30 lasts 0:55:36 hours
# Cycle 31 lasts 1:14:55 hours
# Cycle 32 lasts 0:52:01 hours
# Cycle 33 lasts 0:55:36 hours
# Cycle 34 lasts 1:09:41 hours
# Cycle 35 lasts 1:29:15 hours
# Cycle 36 lasts 1:29:15 hours
# Cycle 37 lasts 1:25:30 hours
# Cycle 38 lasts 1:29:15 hours
# Cycle 39 lasts 1:22:38 hours
# Cycle 40 lasts 1:03:16 hours
# Cycle 41 lasts 1:25:30 hours
# Cycle 42 lasts 1:09:41 hours
# Cycle 43 lasts 0:58:24 hours
# Cycle 44 lasts 1:09:41 hours
# Cycle 45 lasts 0:58:24 hours
# Cycle 46 lasts 1:09:41 hours
# Cycle 47 lasts 1:34:37 hours
# Cycle 48 lasts 1:02:30 hours
# Cycle 49 lasts 0:55:36 hours
# Cycle 50 lasts 1:24:29 hours
# Cycle 51 lasts 0:52:01 hours
# Cycle 52 lasts 1:24:29 hours
# Cycle 53 lasts 1:06:48 hours
# Cycle 54 lasts 1:29:15 hours
# Cycle 55 lasts 1:17:40 hours
# Cycle 56 lasts 1:25:30 hours
# Cycle 57 lasts 0:55:36 hours
# Cycle 58 lasts 1:29:38 hours
# Cycle 59 lasts 1:02:30 hours
# Cycle 60 lasts 0:58:24 hours
# Cycle 61 lasts 0:52:01 hours
# Cycle 62 lasts 1:29:38 hours
# Cycle 63 lasts 1:14:55 hours
# Cycle 64 lasts 1:29:38 hours
# Cycle 65 lasts 1:29:38 hours
# Cycle 66 lasts 1:06:48 hours
# Cycle 67 lasts 1:25:30 hours
# Cycle 68 lasts 1:34:37 hours
# Cycle 69 lasts 1:25:30 hours
# Cycle 70 lasts 1:03:16 hours
# Cycle 71 lasts 1:14:58 hours
# Cycle 72 lasts 1:03:16 hours
# Cycle 73 lasts 1:29:15 hours
# Cycle 74 lasts 1:06:48 hours
# Cycle 75 lasts 1:34:37 hours
# Cycle 76 lasts 1:17:40 hours
#
# Min value is 3121, max_value is 5677
#
# Unit 15 has flight class: 2 (3-5 hours)
#
# Cycle 1 lasts 1:34:56 hours
# Cycle 2 lasts 2:33:59 hours
# Cycle 3 lasts 2:32:58 hours
# Cycle 4 lasts 2:30:34 hours
# Cycle 5 lasts 2:46:00 hours
# Cycle 6 lasts 3:24:55 hours
# Cycle 7 lasts 2:17:07 hours
# Cycle 8 lasts 1:57:14 hours
# Cycle 9 lasts 3:09:15 hours
# Cycle 10 lasts 2:36:47 hours
# Cycle 11 lasts 2:26:57 hours
# Cycle 12 lasts 2:54:08 hours
# Cycle 13 lasts 1:59:28 hours
# Cycle 14 lasts 2:37:27 hours
# Cycle 15 lasts 2:55:37 hours
# Cycle 16 lasts 2:36:47 hours
# Cycle 17 lasts 2:11:29 hours
# Cycle 18 lasts 2:55:37 hours
# Cycle 19 lasts 2:34:57 hours
# Cycle 20 lasts 2:26:14 hours
# Cycle 21 lasts 2:28:20 hours
# Cycle 22 lasts 2:03:55 hours
# Cycle 23 lasts 3:07:04 hours
# Cycle 24 lasts 1:33:45 hours
# Cycle 25 lasts 3:08:39 hours
# Cycle 26 lasts 2:34:57 hours
# Cycle 27 lasts 2:34:09 hours
# Cycle 28 lasts 2:08:38 hours
# Cycle 29 lasts 2:34:28 hours
# Cycle 30 lasts 2:48:59 hours
# Cycle 31 lasts 1:58:21 hours
# Cycle 32 lasts 3:04:28 hours
# Cycle 33 lasts 1:56:49 hours
# Cycle 34 lasts 2:51:12 hours
# Cycle 35 lasts 2:55:59 hours
# Cycle 36 lasts 2:16:37 hours
# Cycle 37 lasts 2:12:58 hours
# Cycle 38 lasts 2:03:55 hours
# Cycle 39 lasts 2:36:47 hours
# Cycle 40 lasts 2:15:11 hours
# Cycle 41 lasts 2:50:40 hours
# Cycle 42 lasts 2:59:58 hours
# Cycle 43 lasts 2:25:21 hours
# Cycle 44 lasts 2:26:49 hours
# Cycle 45 lasts 3:17:52 hours
# Cycle 46 lasts 2:34:57 hours
# Cycle 47 lasts 2:49:02 hours
# Cycle 48 lasts 3:04:11 hours
# Cycle 49 lasts 2:51:12 hours
# Cycle 50 lasts 3:09:17 hours
# Cycle 51 lasts 2:46:00 hours
# Cycle 52 lasts 1:06:15 hours
# Cycle 53 lasts 2:06:49 hours
# Cycle 54 lasts 2:07:38 hours
# Cycle 55 lasts 2:34:09 hours
# Cycle 56 lasts 2:42:31 hours
# Cycle 57 lasts 3:07:04 hours
# Cycle 58 lasts 1:32:42 hours
# Cycle 59 lasts 2:58:04 hours
# Cycle 60 lasts 3:04:28 hours
# Cycle 61 lasts 2:25:21 hours
# Cycle 62 lasts 2:42:31 hours
# Cycle 63 lasts 1:58:21 hours
# Cycle 64 lasts 3:05:01 hours
# Cycle 65 lasts 2:39:10 hours
# Cycle 66 lasts 2:55:59 hours
# Cycle 67 lasts 3:03:55 hours
#
# Min value is 3975, max_value is 12295
